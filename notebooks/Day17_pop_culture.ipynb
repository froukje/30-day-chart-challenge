# %% [markdown]
# # Objective
#
# **Day 17 of the [#30DayChartChallenge challenge](https://github.com/Z3tt/30DayChartChallenge_Collection2021/blob/main/README.md)**
#
# **Topic: 17. pop culture**

# %% [markdown]
# # Setup

# %%
from pywaffle import Waffle
import matplotlib.pyplot as plt
from matplotlib import cm

# %% [markdown]
# # Plot

# %%
colors = ['#FF0000', '#FFA500', '#FFFF00', '#008000', '#0000FF', '#4B0082', '#EE82EE']
fig = plt.figure(
    FigureClass=Waffle,
    rows=6,
    values=[2, 2, 2, 1, 2, 2, 1, 2, 2, 2, 1, 2, 2, 1, 2, 2, 2, 1, 2, 2, 1, 2, 2, 2, 1, 2, 2, 1, 2, 2, 2],
    colors=[colors[6], colors[5], colors[4], colors[6], colors[5], colors[4], colors[3], colors[5], 
            colors[4], colors[3], colors[5], colors[4], colors[3], colors[2], colors[4], colors[3],
           colors[2], colors[4], colors[3], colors[2], colors[1], colors[3], colors[2], colors[1],
           colors[3], colors[2], colors[1], colors[0], colors[2], colors[1], colors[0]],
    icons='star',
    font_size=36
)
fig.text(
    x=0.5,
    y=0.5,
    s="Pop \nCulture",
    ha="center",
    va="center",
    rotation=30,
    fontsize=50,
    color='#ff3399',
    alpha=1,
    fontfamily='cursive',
    bbox={
        'boxstyle': 'round4', 
        'lw': 5, 
        'ec': '#ff3399', 
        'fc': 'white', 
        'alpha': .9
    }
)
fig.set_facecolor('#00ccff')
plt.savefig("../plots/day17_pop_culture.png")
# Out:
# <Waffle size 432x288 with 1 Axes>

# %% [markdown]
# # Objective
#
# **Day 30 of the [#30DayChartChallenge challenge](https://github.com/Z3tt/30DayChartChallenge_Collection2021/blob/main/README.md)**
#
# **Topic: 30. 3D**

# %% [markdown]
# # Setup

# %%
import plotly.graph_objects as go
import numpy as np
import psutil

# %% [markdown]
# # Plot

# %%
X, Y, Z = np.mgrid[:1:20j, :1:20j, :1:20j]
vol = (X - 1)**2 + (Y - 1)**2 + Z**2


fig = go.Figure(data=go.Volume(
    x=X.flatten(),
    y=Y.flatten(),
    z=Z.flatten(),
    value=vol.flatten(),
    isomin=0.1,
    isomax=0.8,
    opacity=0.2, # needs to be small to see through all surfaces
    surface_count=21, # needs to be a large number for good volume rendering
    colorscale='hsv',
    ))
fig.show()
#plt.savefig("../plots/day30_3D.png")
# Out:
# <div>                            <div id="2b0df11a-ca4b-4be8-b6cc-50c532570064" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("2b0df11a-ca4b-4be8-b6cc-50c532570064")) {                    Plotly.newPlot(                        "2b0df11a-ca4b-4be8-b6cc-50c532570064",                        [{"colorscale": [[0.0, "#ff0000"], [0.1111111111111111, "#ffa700"], [0.2222222222222222, "#afff00"], [0.3333333333333333, "#08ff00"], [0.4444444444444444, "#00ff9f"], [0.5555555555555556, "#00b7ff"], [0.6666666666666666, "#0010ff"], [0.7777777777777778, "#9700ff"], [0.8888888888888888, "#ff00bf"], [1.0, "#ff0000"]], "isomax": 0.8, "isomin": 0.1, "opacity": 0.2, "surface": {"count": 21}, "type": "volume", "value": [2.0, 2.0027700831024933, 2.011080332409972, 2.0249
# ...

# %%
N = 100
x = np.random.rand(N)
y = np.random.rand(N)
z = np.random.rand(N)

colors = np.random.rand(N)
sz = np.random.rand(N) * 30
#z = np.linspace(0, 10, 50)
#x = np.cos(z)
#y = np.sin(z)
fig = go.Figure()
fig.add_trace(go.Scatter3d(
    x=x,
    y=y,
    z=z,
    mode="markers",
    marker=go.scatter3d.Marker(
        size=sz,
        color=colors,
        opacity=0.6,
        colorscale="hsv"
    )
))
fig.update_layout(scene_xaxis_showticklabels=False,
                  scene_yaxis_showticklabels=False,
                  scene_zaxis_showticklabels=False)
fig.show()

fig.write_image("../plots/day30_3D.png")
# Out:
# <div>                            <div id="b79ac965-ddfd-4693-bec5-7dd5ecbc6359" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("b79ac965-ddfd-4693-bec5-7dd5ecbc6359")) {                    Plotly.newPlot(                        "b79ac965-ddfd-4693-bec5-7dd5ecbc6359",                        [{"marker": {"color": [0.2501148601549127, 0.0015811758522702446, 0.21482847738718214, 0.3534072758521636, 0.007702588630178364, 0.13624453562031702, 0.36969244265952683, 0.35232837733649236, 0.1259727711122307, 0.870054603492602, 0.6404370428139281, 0.4578740352526286, 0.47758066648189523, 0.7789138278571782, 0.8228520711672499, 0.6032756085118854, 0.20711610046811368, 0.6281517991059067, 0.9368012906702227, 0.9104983125778042, 0.5037714723719138, 0.5151592350704
# ...

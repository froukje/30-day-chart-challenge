# %% [markdown]
# # Objective
#
# **Day 4 of the [#30DayChartChallenge challenge](https://github.com/Z3tt/30DayChartChallenge_Collection2021/blob/main/README.md)**
#
# **Topic: 4. magigal**
#
# Used Dataset: self

# %% [markdown]
# # Setup

# %%
import matplotlib.pyplot as plt
import numpy as np

# %% [markdown]
# # Data

# %%
wing_left_x = [13, 10, 6, 1, 2, 3, 1, 4, 2, 6, 5, 6, 5, 7, 8, 8, 9, 9, 10, 11, 12, 13, 14, 13]
wing_left_y = [9, 9, 8, 8, 7, 7, 6, 6, 5, 5, 4, 4, 3, 3, 4, 3, 4, 3, 4, 3, 5, 5, 7, 9]
wing_right_x = [19, 21, 24, 29, 28, 30, 28, 30, 27, 30, 27, 29, 26, 27, 24, 25, 23, 23, 20, 20]
wing_right_y = [13, 15, 16, 21, 18, 20, 17, 18, 15, 16, 14, 13, 12, 11, 12, 10, 11, 10, 9, 7]
head_x = [13, 15, 17, 19, 20, 19, 17, 16, 13, 13]
head_y = [9, 8, 8, 9, 11, 13, 14, 14, 12, 9]
nose_x = [17, 17, 20]
nose_y = [8, 10, 11]
front_x = [13, 16, 17]
front_y = [12, 12, 14]
body_x = [13, 14, 16, 17, 17, 18, 19, 20, 20]
body_y = [9, 7, 6, 5, 6, 6, 7, 7, 9]
footl_x = [17, 17, 18, 18, 17]
footl_y = [5, 6, 6, 5, 5]
footr_x = [19, 20, 20, 19, 19]
footr_y = [7, 7, 6, 6, 7]
eyel_x = [15, 16, 16, 15, 15]
eyel_y = [11, 11, 10, 10, 11]
eyer_x = [17, 18, 18, 17, 17]
eyer_y = [12, 12, 11, 11, 12]
env1_x = [17, 16, 18, 23, 21, 20]
env1_y = [5, 4, 1, 5, 8, 7]
env2_x = [16, 20, 21]
env2_y = [4, 4, 8]
tail1_x = [16, 15, 16, 17]
tail1_y = [4, 2, 2, 3]
tail2_x = [22, 24, 23, 23]
tail2_y = [7, 7, 6, 5]
moon_x = [3.5, 4, 5.5, 7, 7.5, 7, 5.5, 4, 3.5]
moon_y = [18.5, 17, 16.5, 17, 18.5, 20, 20.5, 20, 18.5]

main_x = [wing_left_x, wing_right_x, head_x, nose_x, front_x, body_x, tail1_x, tail2_x]
main_y = [wing_left_y, wing_right_y, head_y, nose_y, front_y, body_y, tail1_y, tail2_y]

eyes_x = [eyel_x, eyer_x]
eyes_y = [eyel_y, eyer_y]

other_x = [footl_x, footr_x, env1_x, env2_x, moon_x]
other_y = [footl_y, footr_y, env1_y, env2_y, moon_y]

all_x = main_x + eyes_x + other_x + moon_x
all_y = main_y + eyes_y + other_y + moon_y

fig, ax = plt.subplots(1, 1, figsize=(10,7))

for (x, y) in zip(all_x, all_y):
    
    ax.scatter(x, y, color="white")
    ax.plot(x, y, color="white")
    
    # Redraw the data with low alpha and slighty increased linewidth:
    n_shades = 10
    diff_linewidth = 1.05
    alpha_value = 0.3 / n_shades
    for n in range(1, n_shades+1):
        ax.plot(x, y, marker='o',
                linewidth=2+(diff_linewidth*n),
                alpha=alpha_value,
                color='white')
        
ax.set_facecolor('#212946')
ax.tick_params(top=False, bottom=False, left=False, right=False,
                labelleft=False, labelbottom=False)
plt.savefig("../plots/day4_magical.png")
